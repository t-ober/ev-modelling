# %% [markdown]
# # Aufenthaltsdauer in Zuständen aus Rohdaten

# %% [markdown]
# Offenes / Unklares:
# * Wie umgehen mit Fahrten die nicht zuhause enden?
# * Wie Aufenthaltsdauer des Endzustands berechnen? ->  *Ankuftszeit Endzustand bis erste Abfahrtszeit erste Fahrt?*

# %% [markdown]
# ### Zustände
#
# * Zuhause -> 1
# * Arbeit -> 2
# * Einkaufen -> 3
# * Freizeit -> 4
# * Sonstiges -> 5

# %%
import pandas as pd
import numpy as np 
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\thoma\Desktop\ev-modelling-repo\Data\NHTS_trips_processed.csv')

# %%
df["aufenthalt"] = 0

# %%
filt = df["ST_WOTAG"] < 6
df = df[filt]

# %%
df = df.sort_values(by=['ID', 'W_NR'])

# %%
df.reset_index(inplace=True)

# %%
df.tail(100)
# Out:
#          index          ID  ST_WOTAG  WHYFROM  zweck  W_NR  TRPTRANS   wegkm  \
# 737440  923504   407942332         1        1      5     5         3   9.939
# 737441  923505   407942332         1        5      2     6         3   9.588
# 737442  923506   407942351         1        1      4     1         6  21.831
# 737443  923507   407942351         1        4      4     2         6  21.827
# 737444  923508   407942351         1        4      3     3         6  17.500
# ...        ...         ...       ...      ...    ...   ...       ...     ...
# 737535  745650  4045582510         3        5      5     4         6   4.310
# 737536  745651  4045582510         3        5      3     5         6   3.421
# 737537  745652  4045582510         3        3      1     6         6  11.676
# 737538  745653  4045582510         3        1      2     7         6  55.371
# 737539  745654  4045582510         3        2      1     8         6  56.403
#
#         wegmin_imp1  W_SZ  W_AZ  W_SZ_MIN  W_AZ_MIN  W_SZ_t  aufenthalt
# 737440           10  1500  1510       900       910      60           0
# 737441           10  1615  1625       975       985      65           0
# 737442           20  1000  1020       600       620      40           0
# 737443           29  1530  1559       930       959      62           0
# 737444           21  1715  1736      1035      1056      69           0
# ...             ...   ...   ...       ...       ...     ...         ...
# 737535            7   753   800       473       480      32           0
# 737536           17   803   820       483       500      32           0
# 737537           40   920  1000       560       600      37           0
# 737538           40  1520  1600       920       960      61           0
# 737539           30  2300  2330      1380      1410      92           0
#
# [100 rows x 15 columns]

# %%
df.drop(columns=["index"], inplace=True)

# %%
person_grpd = df.groupby(['ID'], as_index=False)

# %%
def calc_aufenthalt(df):
    rows = df.shape[0]
    for i in range(rows):
        # letzter Trip der Person -> Aufenthalt = Zeit bis zum ersten Trip 
        if (i == rows-1) or (df.at[i+1, "ID"] != df.at[i, "ID"]):
            # Beispiel: Wenn Wegnummer = 3 liegt Index des ersten Wegs 2 Schritte zurück
            index_first_trip = i - (df.at[i, "W_NR"] - 1) 
            start_first_trip = df.at[index_first_trip, "W_SZ_MIN"]
            end_last_trip = df.at[i,"W_AZ_MIN"]
            # Gesamtaufenthalt = 
            # Rest des Tages + Zeit bis zum ersten Trip
            if end_last_trip > start_first_trip:           
                df.at[i, "aufenthalt"] = 1440 - end_last_trip + start_first_trip
            # Wenn letzte Fahrt nach 24:00
            elif end_last_trip < start_first_trip:
                df.at[i, "aufenthalt"] = start_first_trip - end_last_trip
        else:
            end_last_trip = df.at[i, "W_AZ_MIN"]
            start_next_trip = df.at[i+1, "W_SZ_MIN"]
            aufenthalt = start_next_trip - end_last_trip
            # wenn Aufenthalt < 0 ist nächster Trip nach 24:00 
            if aufenthalt < 0:
                aufenthalt = (1440 - end_last_trip) + start_next_trip
            df.at[i, "aufenthalt"] = aufenthalt

# %%
calc_aufenthalt(df)

# %%
filt = df["zweck"] == 1
aufenthalt_zuhause = df[filt]["aufenthalt"]
filt = df["zweck"] == 2
aufenthalt_arbeit = df[filt]["aufenthalt"]
filt = df["zweck"] == 3
aufenthalt_einkaufen = df[filt]["aufenthalt"]
filt = df["zweck"] == 4
aufenthalt_freizeit = df[filt]["aufenthalt"]
filt = df["zweck"] == 5
aufenthalt_sonstiges = df[filt]["aufenthalt"]

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(20,10))
ax1.hist(aufenthalt_zuhause, bins=50);
ax1.set_xlim([0, 1500])
ax2.hist(aufenthalt_arbeit, bins=100);
ax2.set_xlim([0,1000])
ax3.hist(aufenthalt_einkaufen, bins=300);
ax3.set_xlim([0,150])
ax4.hist(aufenthalt_freizeit, bins=200);
ax4.set_xlim([0,300])
ax5.hist(aufenthalt_sonstiges, bins=300);
ax5.set_xlim([0,100])
fig.delaxes(ax6)
