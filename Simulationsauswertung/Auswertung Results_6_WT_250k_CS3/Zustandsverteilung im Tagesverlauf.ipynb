# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pickle
import os

path = r"C:\Users\thoma\Desktop\ev-modelling-repo\Simulationsergebnisse\Results_6_WT_250k_CS3.csv"
df = pd.read_csv(path)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
df.head()
# Out:
#    Trip_id  Trip_no  Whyfrom  Whyto  Departure  Departure_t  Arrival  \
# 0      0.1        1        1      2      360.0           24    362.0
# 1      0.2        2        2      3      795.0           53    796.0
# 2      0.3        3        3      1     1102.0           73   1103.0
# 3      1.1        1        1      3      801.0           53    811.0
# 4      1.2        2        3      1      911.0           61    923.0
#
#    Trip_duration  Distance  Stay_duration  Soc_start  Soc_end  Charge_start  \
# 0            2.0      1.18            433      100.0     99.7         362.0
# 1            1.0      0.33            306      100.0     99.9         796.0
# 2            1.0      0.29            922      100.0     99.9        1103.0
# 3           10.0      5.54            100      100.0     98.6         811.0
# 4           12.0      6.63           1070      100.0     98.4         923.0
#
#    Charge_end
# 0       364.0
# 1       797.0
# 2      1104.0
# 3       828.0
# 4       943.0

# %%
df["Arrival_t"] = df["Arrival"].apply(lambda x: int(round(x/15)))

# %%
driving = [0 for i in range(97)]
at_home = [0 for i in range(97)]
at_work = [0 for i in range(97)]
at_shopping = [0 for i in range(97)]
at_recreational = [0 for i in range(97)]
at_other = [0 for i in range(97)]

states = [driving, at_home, at_work, at_shopping, at_recreational, at_other]

# %%
df.head(50)
# Out:
#     Trip_id  Trip_no  Whyfrom  Whyto  Departure  Departure_t  Arrival  \
# 0       0.1        1        1      2      360.0           24    362.0
# 1       0.2        2        2      3      795.0           53    796.0
# 2       0.3        3        3      1     1102.0           73   1103.0
# 3       1.1        1        1      3      801.0           53    811.0
# 4       1.2        2        3      1      911.0           61    923.0
# 5       2.1        1        1      3      421.0           28    442.0
# 6       2.2        2        3      2      473.0           32    510.0
# 7       2.3        3        2      1     1040.0           69   1087.0
# 8       3.1        1        1      2      438.0           29    464.0
# 9       3.2        2        2      1     1133.0           76   1160.0
# 10      3.3        3        1      2     1360.0           91   1410.0
# 11      4.1        1        1      5      455.0           30    487.0
# 12      4.2        2        5      2      488.0           33    506.0
# 13      4.3        3        2      1      963.0           64    974.0
# 14      5.1        1        1      4      570.0           38    587.0
# 15      5.2        2        4      5      632.0           42    763.0
# 16      5.3        3        5      3      763.0           51    773.0
# 17      5.4        4        3      1      820.0           55    831.0
# 18      6.1        1        1      4      532.0           35    552.0
# 19      6.2        2        4      3      576.0           38    593.0
# 20      6.3        3        3      1      655.0           44    719.0
# 21      6.4        4        1      2      990.0           66   1029.0
# 22      7.1        1        1      2      393.0           26    470.0
# 23      7.2        2        2      4      910.0           61    914.0
# 24      7.3        3        4      1     1054.0           70   1143.0
# 25      8.1        1        1      2      468.0           31    484.0
# 26      8.2        2        2      1      946.0           63    962.0
# 29           13.0      7.58           1404       75.8     66.3         931.0
# 30           15.0      8.26              1      100.0     93.9           NaN
# 31           16.0      9.09             19       93.9     87.1         489.0
# 32            4.0      2.12            673       93.7     92.2         512.0
# 33            5.0      2.59            247      100.0     98.1        1190.0
# 34            5.0      3.07           1406      100.0     97.7           2.0
# 35            7.0      3.75             14      100.0     98.9           NaN
# 36           61.0     34.53             23       98.9     89.2         662.0
# 37           22.0     12.74              7       92.0     88.4           NaN
# 38           12.0      6.75           1422       88.4     86.5         726.0
# 39           16.0      8.85            278      100.0     96.9         449.0
# 40           37.0     21.05           1006      100.0     92.5         764.0
# 41           11.0      6.12              6      100.0     98.3           NaN
# 42           14.0      8.13            951       98.3     96.0         518.0
# 43           70.0     39.85             55      100.0     76.4         745.0
# 44           13.0      7.24            122       88.5     84.2         813.0
# 45           16.0      9.21              5      100.0     94.5           NaN
# 46           34.0     19.58             16       94.5     82.9         990.0
# 47            1.0      0.50             60       86.5     86.2        1007.0
# 48           11.0      6.53             26       99.4     95.5        1078.0
# 49            5.0      3.08              5      100.0     98.2           NaN
#
#     Charge_end  Arrival_t
# 0        364.0         24
# 1        797.0         53
# 2       1104.0         74
# 3        828.0         54
# 4        943.0         62
# 5        470.0         29
# 6        560.0         34
# 7       1150.0         72
# 8        504.0         31
# 9       1201.0         77
# 10        45.0         94
# 11         NaN         32
# 12       559.0         34
# 13       986.0         65
# 14       608.0         39
# 15         NaN         51
# 16       820.0         52
# 17       965.0         55
# 18       576.0         37
# 19       641.0         40
# 20       843.0         48
# 21      1105.0         69
# 22       563.0         31
# 23       919.0         61
# 24      1251.0         76
# 25       502.0         32
# 26       980.0         64
# 27       708.0         46
# 28       918.0         56
# 29      1040.0         62
# 30         NaN         31
# 31       508.0         33
# 32       534.0         34
# 33      1196.0         79
# 34         9.0          0
# 35         NaN         39
# 36       685.0         44
# 37         NaN         47
# 38       835.0         48
# 39       467.0         30
# 40       807.0         51
# 41         NaN         33
# 42       551.0         35
# 43       800.0         50
# 44       885.0         54
# 45         NaN         63
# 46      1006.0         66
# 47      1067.0         67
# 48      1098.0         72
# 49         NaN         74

# %%
# iterieren durch alle Zeilen
rows = df.shape[0]
for i in range (rows-1):
    
    # ZUHAUSE BIS ERSTER TRIP 
    if df.at[i,"Trip_no"] == 1:
        # Fahrzeug zuhause bis zum Zeitpunkt der ersten Abfahrt
        whyfrom = df.at[i, "Whyfrom"]
        for j in range(df.at[i, "Departure_t"]):
            states[whyfrom][j] += 1
    
    # FAHRZUSTAND DEPARTURE - ARRIVAL
    # Fahrzeug im Fahrzustand bis zur Ankunft am Ziel
    for j in range(df.at[i, "Departure_t"], df.at[i, "Arrival_t"]):
        states[0][j] += 1
    
    whyto = df.at[i, "Whyto"]
    # ANKUNFT BIS NÄCHSTER TAG ODER ABFAHRT NÄCHSTER TRIP 
    # wenn letzter Trip der Person: Aufenthalt bis zum nächsten Morgen am Zielzustand
    if df.at[i+1,"Trip_no"] == 1:
        for j in range(df.at[i, "Arrival_t"], 97):
            states[whyto][j] +=1
    else:
        for j in range(df.at[i, "Arrival_t"], df.at[i+1, "Departure_t"]):
            states[whyto][j] +=1

# %%
for i in range(97): 
    print ((states[0][i] + states[1][i] + states[2][i] + states[3][i] + states[4][i] + states[5][i])/250000)
# Out:
# 1.009244
# 1.020448
# 1.026524
# 1.030428
# 1.032768
# 1.034504
# 1.0357
# 1.03664
# 1.037352
# 1.037952
# 1.038428
# 1.038788
# 1.03908
# 1.039308
# 1.03952
# 1.039712
# 1.039876
# 1.039968
# 1.040052
# 1.04014
# 1.040228
# 1.04028
# 1.040344
# 1.040384
# 1.040416
# 1.040436
# 1.040436
# 1.040452
# 1.040484
# 1.040492
# 1.040504
# 1.040508
# 1.040516
# 1.040516
# 1.040528
# 1.040528
# 1.040528
# 1.040544
# 1.04054
# 1.04054
# 1.04054
# 1.04054
# 1.040544
# 1.040544
# 1.040536
# 1.040536
# 1.040536
# 1.040536
# 1.040536
# 1.040536
# 1.040532
# 1.040524
# 1.040524
# 1.040528
# 1.04052
# 1.040512
# 1.040504
# 1.040488
# 1.040472
# 1.040452
# 1.040444
# 1.04042
# 1.040408
# 1.040396
# 1.04036
# 1.040328
# 1.0403
# 1.04028
# 1.040252
# 1.040208
# 1.040176
# 1.040132
# 1.040088
# 1.04002
# 1.039912
# 1.039832
# 1.039752
# 1.039664
# 1.039576
# 1.039468
# 1.039316
# 1.039164
# 1.038944
# 1.038712
# 1.038452
# 1.038064
# 1.037584
# 1.03694
# 1.036244
# 1.0353
# 1.033892
# 1.03218
# 1.02986
# 1.026144
# 1.020192
# 1.008732
# 1.000008

# %%
x = np.linspace(0, 96, 97)

# %%
plt.figure(figsize=(20,10))

plt.bar(x, states[1], label="Zuhause", color='#FFCA3A' )
plt.bar(x, states[2], bottom=states[1], label="Arbeit", color='#FF595E');
plt.bar(x, states[3], bottom=[i+j for i,j in zip(states[1], states[2])], label="Einkaufen", color='#8AC926');
plt.bar(x, states[4], bottom=[i+j+k for i,j,k in zip(states[1], states[2], states[3])], label="Freizeit", color='#1982C4');
plt.bar(x, states[5], bottom=[i+j+k+l for i,j,k,l in zip(states[1], states[2], states[3], states[4])], label="Sonstiges", color='#6A4C93');
plt.bar(x, states[0], bottom=[i+j+k+l+m for i,j,k,l,m in zip(states[1], states[2], states[3], states[4], states[5])], label="Fahrzustand", color="orange");
plt.legend()
